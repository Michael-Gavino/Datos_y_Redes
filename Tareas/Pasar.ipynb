# %%
Un aminoacido siempre va a tener un grupo amino y grupo carboxilo
Un aminoacido siempre va a tener un carbono central.
En algunas ocaciones, no se va a mostrar el carbono central. Recordar que el carbono central siempre está conformado por cuatro enlaces, de los cuales uno es el grupo amino, otro el grupo carboxilo, otro el hidrogeno y otro el R.
Un enlace peptidico siempre va a ser un C=O con N-H

# %%
mkdir /opt/MOPAC #Crea un directorio llamado "MOPAC" dentro del directorio "/opt
# %cd /opt/MOPAC #Cambia el directorio actual de trabajo al recién creado "/opt/MOPAC
# !wget http://openmopac.net/MOPAC2016_for_Linux_64_bit.zip #Descarga un archivo zip desde el URL especificado
# !unzip /opt/MOPAC/MOPAC2016_for_Linux_64_bit.zip #Descomprime el archivo zip descargado en el directorio actual.
# !cp -p /opt/MOPAC/libiomp5.so /usr/lib/ #copia el archivo "libiomp5.so" desde el directorio "/opt/MOPAC" al directorio "/usr/lib/
# !chmod 755 MOPAC2016.exe #Cambia los permisos del archivo "MOPAC2016.exe
# !chmod 777 .

# %%
# Creamos una carpeta de trabajo y entramos
# !mkdir mis_moleculas
# %cd mis_moleculas/

# %%
#Mostramos la linea correspondiente que tenga la cadena HOMO
# !grep HOMO BH_mopac_pm7.out

# %%
#Realizamos el calculo de la energia Egap
BH_Egap_ = 3.189 - (-2.463)
BH_Egap_

# %% [markdown]
# ien, ahora expliquemos que podría significar este cambio. Para empezar, nos damos cuenta que la energía Egap aumentó, esto podría indicar que el cambio ha llevado a una molécula que es menos reactiva químicamente, es decir, que la molécula modificada (Cl) es menos propensa a aceptar o donar electrones, lo que podría implicar una menor reactividad en comparación con la molécula original (H).
